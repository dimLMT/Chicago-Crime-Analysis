# %% [markdown]
# # part1) preparing a crime dataset for time series analysis.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, glob
# Use glob to get all filepaths that match the pattern (*=wildcard)
all_files = sorted(glob.glob("Data/Chicago-Crime*.csv"))
all_files
# Out:
# ['Data\\Chicago-Crime_2001.csv',
#  'Data\\Chicago-Crime_2002.csv',
#  'Data\\Chicago-Crime_2003.csv',
#  'Data\\Chicago-Crime_2004.csv',
#  'Data\\Chicago-Crime_2005.csv',
#  'Data\\Chicago-Crime_2006.csv',
#  'Data\\Chicago-Crime_2007.csv',
#  'Data\\Chicago-Crime_2008.csv',
#  'Data\\Chicago-Crime_2009.csv',
#  'Data\\Chicago-Crime_2010.csv',
#  'Data\\Chicago-Crime_2011.csv',
#  'Data\\Chicago-Crime_2012.csv',
#  'Data\\Chicago-Crime_2013.csv',
#  'Data\\Chicago-Crime_2014.csv',
#  'Data\\Chicago-Crime_2015.csv',
#  'Data\\Chicago-Crime_2016.csv',
#  'Data\\Chicago-Crime_2017.csv',
#  'Data\\Chicago-Crime_2018.csv',
#  'Data\\Chicago-Crime_2019.csv',
#  'Data\\Chicago-Crime_2020.csv',
#  'Data\\Chicago-Crime_2021.csv',
#  'Data\\Chicago-Crime_2022.csv']

# %%
dff = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
dff.info()
dff.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7713109 entries, 0 to 7713108
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Date                  object
#  2   Primary Type          object
#  3   Description           object
#  4   Location Description  object
#  5   Arrest                bool
#  6   Domestic              bool
#  7   Beat                  int64
#  8   District              float64
#  9   Ward                  float64
#  10  Latitude              float64
#  11  Longitude             float64
# dtypes: bool(2), float64(4), int64(2), object(4)
# memory usage: 603.2+ MB
#         ID                    Date     Primary Type          Description  \
# 0  1326041  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
# 1  1319931  01/01/2001 01:00:00 PM          BATTERY               SIMPLE
# 2  1324743  01/01/2001 01:00:00 PM         GAMBLING  ILLEGAL ILL LOTTERY
# 3  1310717  01/01/2001 01:00:00 AM  CRIMINAL DAMAGE           TO VEHICLE
# 4  1318099  01/01/2001 01:00:00 AM          BATTERY               SIMPLE
#
#       Location Description  Arrest  Domestic  Beat  District  Ward   Latitude  \
# 0                RESIDENCE   False     False  1624      16.0   NaN  41.957850
# 1                RESIDENCE   False      True   825       8.0   NaN  41.783892
# 2                   STREET    True     False   313       3.0   NaN  41.780412
# 3                   STREET   False     False  2424      24.0   NaN  42.012391
# 4  RESIDENCE PORCH/HALLWAY   False      True   214       2.0   NaN  41.819538
#
#    Longitude
# 0 -87.749185
# 1 -87.684841
# 2 -87.611970
# 3 -87.678032
# 4 -87.620020

# %%
df=dff.copy()
df['Datetime']= pd.to_datetime(df['Date'],format="%m/%d/%Y %I:%M:%S %p")
df['Datetime'].head()
# Out:
# 0   2001-01-01 01:00:00
# 1   2001-01-01 13:00:00
# 2   2001-01-01 13:00:00
# 3   2001-01-01 01:00:00
# 4   2001-01-01 01:00:00
# Name: Datetime, dtype: datetime64[ns]

# %%
df= df.drop(['Date'], axis=1)
df= df.set_index('Datetime')
df['District'] = df['District'].astype('str')
df
# Out:
#                            ID        Primary Type  \
# Datetime
# 2001-01-01 01:00:00   1326041             BATTERY
# 2001-01-01 13:00:00   1319931             BATTERY
# 2001-01-01 13:00:00   1324743            GAMBLING
# 2001-01-01 01:00:00   1310717     CRIMINAL DAMAGE
# 2001-01-01 01:00:00   1318099             BATTERY
# ...                       ...                 ...
# 2022-12-31 12:50:00  12938029             ASSAULT
# 2022-12-31 12:50:00  12937822             ASSAULT
# 2022-12-31 00:52:00  12937583             BATTERY
# 2022-12-31 12:52:00  12938420             ASSAULT
# 2022-12-31 12:59:00  12939906  DECEPTIVE PRACTICE
#
#                                                  Description  \
# Datetime
# 2001-01-01 01:00:00                                   SIMPLE
# 2001-01-01 13:00:00                                   SIMPLE
# 2001-01-01 13:00:00                      ILLEGAL ILL LOTTERY
# 2001-01-01 01:00:00                               TO VEHICLE
# 2001-01-01 01:00:00                                   SIMPLE
# ...                                                      ...
# 2022-12-31 12:50:00                                   SIMPLE
# 2022-12-31 12:50:00                     AGGRAVATED - HANDGUN
# 2022-12-31 00:52:00                                   SIMPLE
# 2022-12-31 12:52:00                                   SIMPLE
# 2022-12-31 12:59:00  FINANCIAL IDENTITY THEFT $300 AND UNDER
#
#                              Location Description  Arrest  Domestic  Beat  \
# Datetime
# 2001-01-01 01:00:00                     RESIDENCE   False     False  1624
# 2001-01-01 13:00:00                     RESIDENCE   False      True   825
# 2001-01-01 13:00:00                        STREET    True     False   313
# 2001-01-01 01:00:00                        STREET   False     False  2424
# 2001-01-01 01:00:00       RESIDENCE PORCH/HALLWAY   False      True   214
# ...                                           ...     ...       ...   ...
# 2022-12-31 12:50:00                     APARTMENT   False     False  1014
# 2022-12-31 12:50:00                     APARTMENT   False      True   733
# 2022-12-31 00:52:00                    BARBERSHOP   False     False  1135
# 2022-12-31 12:52:00  COMMERCIAL / BUSINESS OFFICE   False     False  1432
# 2022-12-31 12:59:00                     RESIDENCE   False     False  1511
#
#                     District  Ward   Latitude  Longitude
# Datetime
# 2001-01-01 01:00:00     16.0   NaN  41.957850 -87.749185
# 2001-01-01 13:00:00      8.0   NaN  41.783892 -87.684841
# 2001-01-01 13:00:00      3.0   NaN  41.780412 -87.611970
# 2001-01-01 01:00:00     24.0   NaN  42.012391 -87.678032
# 2001-01-01 01:00:00      2.0   NaN  41.819538 -87.620020
# ...                      ...   ...        ...        ...
# 2022-12-31 12:50:00     10.0  24.0  41.855911 -87.719966
# 2022-12-31 12:50:00      7.0   6.0  41.766546 -87.645669
# 2022-12-31 00:52:00     11.0  28.0  41.868829 -87.686098
# 2022-12-31 12:52:00     14.0  32.0  41.930693 -87.685657
# 2022-12-31 12:59:00     15.0  29.0        NaN        NaN
#
# [7713109 rows x 11 columns]

# %% [markdown]
# # part2) answer the provided stakeholder questions and support answers with visualizations.
# ### 1. Comparing Police Districts
# - Which district had the most crimes in 2022?
# - Which had the least?

# %%
crimes_by_District = df.resample('Y')['District'].value_counts(ascending=True)
crimes_by_District
# Out:
# Datetime    District
# 2001-12-31  20.0         9989
#             17.0        14488
#             1.0         14861
#             22.0        14955
#             24.0        15111
#                         ...
# 2022-12-31  11.0        13457
#             4.0         13931
#             12.0        14341
#             6.0         14694
#             8.0         14805
# Name: District, Length: 513, dtype: int64

# %%
crimes_by_District.head().index
# Out:
# MultiIndex([('2001-12-31', '20.0'),
#             ('2001-12-31', '17.0'),
#             ('2001-12-31',  '1.0'),
#             ('2001-12-31', '22.0'),
#             ('2001-12-31', '24.0')],
#            names=['Datetime', 'District'])

# %%
crimes_by_District=crimes_by_District.loc['2022']
crimes_by_District
# Out:
# Datetime    District
# 2022-12-31  31.0           15
#             20.0         4960
#             17.0         6997
#             22.0         7671
#             14.0         8158
#             15.0         8308
#             24.0         8469
#             16.0         9226
#             5.0          9773
#             10.0         9961
#             7.0         10319
#             9.0         10376
#             2.0         11793
#             3.0         11937
#             25.0        11951
#             19.0        12243
#             18.0        12429
#             1.0         13044
#             11.0        13457
#             4.0         13931
#             12.0        14341
#             6.0         14694
#             8.0         14805
# Name: District, dtype: int64

# %%
##  Getting indices for min and max
crimes_by_District.agg(['idxmin','idxmax'])
# Out:
# idxmin    (2022-12-31 00:00:00, 31.0)
# idxmax     (2022-12-31 00:00:00, 8.0)
# Name: District, dtype: object

# %%
crimes_by_District.to_frame('Total # of Crimes').style.bar()
# Out:
# <style type="text/css">
# #T_6d0bf_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.1%, transparent 0.1%);
# }
# #T_6d0bf_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.5%, transparent 33.5%);
# }
# #T_6d0bf_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 47.3%, transparent 47.3%);
# }
# #T_6d0bf_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 51.8%, transparent 51.8%);
# }
# #T_6d0bf_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.1%, transparent 55.1%);
# }
# #T_6d0bf_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.1%, transparent 56.1%);
# }
# #T_6d0bf_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 57.2%, transparent 57.2%);
# }
# #T_6d0bf_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.3%, transparent 62.3%);
# }
# #T_6d0bf_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 66.0%, transparent 66.0%);
# }
# #T_6d0bf_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.3%, transparent 67.3%);
# }
# #T_6d0bf_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 69.7%, transparent 69.7%);
# }
# #T_6d0bf_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 70.1%, transparent 70.1%);
# }
# #T_6d0bf_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 79.7%, transparent 79.7%);
# }
# #T_6d0bf_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.6%, transparent 80.6%);
# }
# #T_6d0bf_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.7%, transparent 80.7%);
# }
# #T_6d0bf_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 82.7%, transparent 82.7%);
# }
# #T_6d0bf_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.0%, transparent 84.0%);
# }
# #T_6d0bf_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 88.1%, transparent 88.1%);
# }
# #T_6d0bf_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 90.9%, transparent 90.9%);
# }
# #T_6d0bf_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 94.1%, transparent 94.1%);
# }
# #T_6d0bf_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 96.9%, transparent 96.9%);
# }
# #T_6d0bf_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 99.3%, transparent 99.3%);
# }
# #T_6d0bf_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_6d0bf">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d0bf_level0_col0" class="col_heading level0 col0" >Total # of Crimes</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Datetime</th>
#       <th class="index_name level1" >District</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d0bf_level0_row0" class="row_heading level0 row0" rowspan="23">2022-12-31 00:00:00</th>
#       <th id="T_6d0bf_level1_row0" class="row_heading level1 row0" >31.0</th>
#       <td id="T_6d0bf_row0_col0" class="data row0 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row1" class="row_heading level1 row1" >20.0</th>
#       <td id="T_6d0bf_row1_col0" class="data row1 col0" >4960</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row2" class="row_heading level1 row2" >17.0</th>
#       <td id="T_6d0bf_row2_col0" class="data row2 col0" >6997</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row3" class="row_heading level1 row3" >22.0</th>
#       <td id="T_6d0bf_row3_col0" class="data row3 col0" >7671</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row4" class="row_heading level1 row4" >14.0</th>
#       <td id="T_6d0bf_row4_col0" class="data row4 col0" >8158</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row5" class="row_heading level1 row5" >15.0</th>
#       <td id="T_6d0bf_row5_col0" class="data row5 col0" >8308</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row6" class="row_heading level1 row6" >24.0</th>
#       <td id="T_6d0bf_row6_col0" class="data row6 col0" >8469</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row7" class="row_heading level1 row7" >16.0</th>
#       <td id="T_6d0bf_row7_col0" class="data row7 col0" >9226</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row8" class="row_heading level1 row8" >5.0</th>
#       <td id="T_6d0bf_row8_col0" class="data row8 col0" >9773</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row9" class="row_heading level1 row9" >10.0</th>
#       <td id="T_6d0bf_row9_col0" class="data row9 col0" >9961</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row10" class="row_heading level1 row10" >7.0</th>
#       <td id="T_6d0bf_row10_col0" class="data row10 col0" >10319</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row11" class="row_heading level1 row11" >9.0</th>
#       <td id="T_6d0bf_row11_col0" class="data row11 col0" >10376</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row12" class="row_heading level1 row12" >2.0</th>
#       <td id="T_6d0bf_row12_col0" class="data row12 col0" >11793</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row13" class="row_heading level1 row13" >3.0</th>
#       <td id="T_6d0bf_row13_col0" class="data row13 col0" >11937</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row14" class="row_heading level1 row14" >25.0</th>
#       <td id="T_6d0bf_row14_col0" class="data row14 col0" >11951</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row15" class="row_heading level1 row15" >19.0</th>
#       <td id="T_6d0bf_row15_col0" class="data row15 col0" >12243</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row16" class="row_heading level1 row16" >18.0</th>
#       <td id="T_6d0bf_row16_col0" class="data row16 col0" >12429</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row17" class="row_heading level1 row17" >1.0</th>
#       <td id="T_6d0bf_row17_col0" class="data row17 col0" >13044</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row18" class="row_heading level1 row18" >11.0</th>
#       <td id="T_6d0bf_row18_col0" class="data row18 col0" >13457</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row19" class="row_heading level1 row19" >4.0</th>
#       <td id="T_6d0bf_row19_col0" class="data row19 col0" >13931</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row20" class="row_heading level1 row20" >12.0</th>
#       <td id="T_6d0bf_row20_col0" class="data row20 col0" >14341</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row21" class="row_heading level1 row21" >6.0</th>
#       <td id="T_6d0bf_row21_col0" class="data row21 col0" >14694</td>
#     </tr>
#     <tr>
#       <th id="T_6d0bf_level1_row22" class="row_heading level1 row22" >8.0</th>
#       <td id="T_6d0bf_row22_col0" class="data row22 col0" >14805</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Answer: In 2022, the district 8 had the most crimes, the district 31 had the least.
# ### 2. Crimes Across the Years:
# - Is the total number of crimes increasing or decreasing across the year?
# - Are there any individual crimes that are doing the opposite (e.g., decreasing when overall crime is increasing or vice-versa)?

# %%
years = df.index.year
crimes_by_Year = years.value_counts().sort_index()
crimes_by_Year
# Out:
# 2001    485886
# 2002    486807
# 2003    475985
# 2004    469422
# 2005    453773
# 2006    448179
# 2007    437087
# 2008    427183
# 2009    392827
# 2010    370513
# 2011    351993
# 2012    336319
# 2013    307536
# 2014    275789
# 2015    264787
# 2016    269823
# 2017    269100
# 2018    268899
# 2019    261325
# 2020    212194
# 2021    208824
# 2022    238858
# Name: Datetime, dtype: int64

# %%
crimes_by_Year.plot(xlabel='Time',ylabel='Total # of Crimes');

# %%
crimes_by_Year = df.groupby('Primary Type').resample('Y').size().sort_index()
crimes_by_Year
# Out:
# Primary Type       Datetime
# ARSON              2001-12-31    1011
#                    2002-12-31    1032
#                    2003-12-31     955
#                    2004-12-31     778
#                    2005-12-31     691
#                                  ...
# WEAPONS VIOLATION  2018-12-31    5456
#                    2019-12-31    6339
#                    2020-12-31    8432
#                    2021-12-31    8980
#                    2022-12-31    8766
# Length: 723, dtype: int64

# %%
## convert to dataframe and reset_index()
plot_df = crimes_by_Year.to_frame('# of Crimes').reset_index()
plot_df
# Out:
#           Primary Type   Datetime  # of Crimes
# 0                ARSON 2001-12-31         1011
# 1                ARSON 2002-12-31         1032
# 2                ARSON 2003-12-31          955
# 3                ARSON 2004-12-31          778
# 4                ARSON 2005-12-31          691
# ..                 ...        ...          ...
# 718  WEAPONS VIOLATION 2018-12-31         5456
# 719  WEAPONS VIOLATION 2019-12-31         6339
# 720  WEAPONS VIOLATION 2020-12-31         8432
# 721  WEAPONS VIOLATION 2021-12-31         8980
# 722  WEAPONS VIOLATION 2022-12-31         8766
#
# [723 rows x 3 columns]

# %%
import datetime as dt
plot_df['Year']= plot_df['Datetime'].dt.year

# %%
g = sns.catplot(data=plot_df, x='Year', y='# of Crimes',
                kind='point',aspect=2, height=7,
                hue='Primary Type', col='Primary Type',col_wrap=2,
                sharey=False, sharex=False)
[ax.grid(axis='x') for ax in g.axes];

# %% [markdown]
# Answer: the total number of crimes is decreasing across the year, but there are individual crimes that are doing the opposite,
# such as concealed carry license violation, eaapons violation, obscenity, deceptive practice...
# ### 3.  Comparing AM vs. PM Rush Hour:
# - Are crimes more common during AM rush hour or PM rush hour?
# (You can consider any crime that occurred between 7 AM - 10 AM as AM rush hour.
# You can consider any crime that occurred between 4 - 7 PM as PM rush hour.)
# - What are the top 5 most common crimes during AM rush hour? What are the top 5 most common crimes during PM rush hour?
# - Are Motor Vehicle Thefts more common during AM rush hour or PM Rush Hour?

# %%
# adding hour of the day (12am=0) 
df['HourOfDay'] = df.index.hour 
sns.countplot(data=df, x='HourOfDay',palette='dark');

# %%
crimes_by_Hour = df.groupby("HourOfDay")['Primary Type'].value_counts()
crimes_by_Hour
# Out:
# HourOfDay  Primary Type
# 0          THEFT                               91882
#            BATTERY                             71777
#            CRIMINAL DAMAGE                     64386
#            DECEPTIVE PRACTICE                  40410
#            OTHER OFFENSE                       27799
#                                                ...
# 23         PUBLIC INDECENCY                        6
#            NON-CRIMINAL                            4
#            RITUALISM                               3
#            HUMAN TRAFFICKING                       1
#            NON-CRIMINAL (SUBJECT SPECIFIED)        1
# Name: Primary Type, Length: 800, dtype: int64

# %%
AM_crime=crimes_by_Hour.loc[7]+crimes_by_Hour.loc[8]+crimes_by_Hour.loc[9]+crimes_by_Hour.loc[10]
AM_crime.sort_values(ascending=False)
# Out:
# Primary Type
# THEFT                                260759
# BATTERY                              158475
# CRIMINAL DAMAGE                      109089
# BURGLARY                              96219
# OTHER OFFENSE                         89870
# DECEPTIVE PRACTICE                    80006
# ASSAULT                               73636
# NARCOTICS                             67032
# MOTOR VEHICLE THEFT                   54035
# CRIMINAL TRESPASS                     30493
# ROBBERY                               26337
# PROSTITUTION                          12215
# OFFENSE INVOLVING CHILDREN             8835
# WEAPONS VIOLATION                      8435
# PUBLIC PEACE VIOLATION                 5460
# SEX OFFENSE                            5005
# CRIM SEXUAL ASSAULT                    2567
# KIDNAPPING                             1649
# INTERFERENCE WITH PUBLIC OFFICER       1380
# ARSON                                  1139
# HOMICIDE                               1133
# STALKING                                928
# INTIMIDATION                            907
# GAMBLING                                652
# CRIMINAL SEXUAL ASSAULT                 544
# LIQUOR LAW VIOLATION                    409
# CONCEALED CARRY LICENSE VIOLATION       157
# OBSCENITY                               145
# NON-CRIMINAL                             40
# PUBLIC INDECENCY                         40
# NON - CRIMINAL                           19
# HUMAN TRAFFICKING                        19
# OTHER NARCOTIC VIOLATION                 18
# Name: Primary Type, dtype: int64

# %%
PM_crime=crimes_by_Hour.loc[16]+crimes_by_Hour.loc[18]+crimes_by_Hour.loc[19]+crimes_by_Hour.loc[17]
PM_crime.sort_values(ascending=False)
# Out:
# Primary Type
# THEFT                                379122.0
# BATTERY                              288003.0
# CRIMINAL DAMAGE                      183423.0
# NARCOTICS                            164754.0
# ASSAULT                              118179.0
# OTHER OFFENSE                         98687.0
# BURGLARY                              78604.0
# MOTOR VEHICLE THEFT                   74678.0
# ROBBERY                               61775.0
# DECEPTIVE PRACTICE                    58973.0
# CRIMINAL TRESPASS                     48564.0
# WEAPONS VIOLATION                     20485.0
# OFFENSE INVOLVING CHILDREN            13278.0
# PUBLIC PEACE VIOLATION                12135.0
# PROSTITUTION                           8125.0
# SEX OFFENSE                            5865.0
# GAMBLING                               4905.0
# INTERFERENCE WITH PUBLIC OFFICER       4403.0
# LIQUOR LAW VIOLATION                   4168.0
# CRIM SEXUAL ASSAULT                    3874.0
# HOMICIDE                               2227.0
# KIDNAPPING                             2092.0
# ARSON                                  1523.0
# INTIMIDATION                           1008.0
# STALKING                                906.0
# CRIMINAL SEXUAL ASSAULT                 824.0
# CONCEALED CARRY LICENSE VIOLATION       187.0
# OBSCENITY                               134.0
# PUBLIC INDECENCY                         47.0
# NON-CRIMINAL                             40.0
# OTHER NARCOTIC VIOLATION                 37.0
# HUMAN TRAFFICKING                        12.0
# NON - CRIMINAL                            5.0
# NON-CRIMINAL (SUBJECT SPECIFIED)          NaN
# RITUALISM                                 NaN
# Name: Primary Type, dtype: float64

# %%
ax = AM_crime.sort_values().head().plot(kind='barh',figsize=(6,6))
ax.set(title='Most Common Crimes for AM rush hour', xlabel='# of Crimes');

# %%
ax = PM_crime.sort_values().dropna().head().plot(kind='barh',figsize=(6,6))
ax.set(title='Most Common Crimes for PM rush hour', xlabel='# of Crimes');

# %%
print(f'there are total crimes ~{AM_crime.sum()} during AM rush hour, less than total crimes ~{PM_crime.sum()} during PM rush hour over the 20 years.')
print(f'there are ~54035 MOTOR VEHICLE THEFT during AM rush hour, less than ~74678 during PM rush hour.')
# Out:
# there are total crimes ~1097647 during AM rush hour, less than total crimes ~1641042.0 during PM rush hour over the 20 years.
# there are ~54035 MOTOR VEHICLE THEFT during AM rush hour, less than ~74678 during PM rush hour.
